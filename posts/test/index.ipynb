# %% [raw]
# ---
# title: "Matplotlib Demo"
# author: "Norah Smith"
# date: "5/22/2021"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# hello

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = np.linspace(0, 2, 100)
ys = np.exp(xs)

plt.plot(xs, ys)
